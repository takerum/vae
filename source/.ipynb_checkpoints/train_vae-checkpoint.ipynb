# %%
from chainer import FunctionSet,Variable

import chainer.functions as F
import chainer.optimizers as optimizers
import numpy
from vae_mnist import VAE_MNIST_b
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #Training Variatoinal Auto-encoder

# %%
vae = VAE_MNIST_b()
optimizer = optimizers.Adam(alpha=0.001)
optimizer.setup(vae)

from sklearn.datasets import fetch_mldata
mnist = fetch_mldata('MNIST original')
x_all = mnist.data.astype(numpy.float32)/255
#y_all = mnist.target.astype(numpy.int32)
x_train, x_test = numpy.split(x_all, [60000])
#y_train, y_test = numpy.split(y_all, [60000])

num_epochs = 100

train_free_energies = numpy.zeros(num_epochs)
test_free_energies = numpy.zeros(num_epochs)

batchsize = 100
for epoch in xrange(num_epochs):
    indexes = numpy.random.permutation(60000)
    n_batch = indexes.shape[0]/batchsize
    sum_free_energy = 0

    for i in xrange(0, 60000, batchsize):
        x_batch = Variable(x_train[indexes[i : i + batchsize]])
        free_energy = vae.free_energy(x_batch)
        sum_free_energy += free_energy.data
        optimizer.zero_grads()
        free_energy.backward()
        optimizer.update()
    
    indexes = numpy.random.permutation(10000)   
    sum_test_free_energy = 0
    for i in xrange(0, 10000, batchsize):
        x_batch = Variable(x_test[indexes[i : i + batchsize]])
        free_energy = vae.free_energy(x_batch)
        sum_test_free_energy += free_energy.data

    train_free_energies[epoch] = sum_free_energy/60000
    test_free_energies[epoch] = sum_test_free_energy/10000
         
    print '[epoch ' +  str(epoch) +']'
    print 'train free energy:' + str(train_free_energies[epoch])
    print 'test free energy:' + str(test_free_energies[epoch])

fontsize = 14
plt.plot(numpy.arange(0,num_epochs),train_free_energies,label='train free energy')
plt.plot(numpy.arange(0,num_epochs),test_free_energies,label='test free energy')
plt.legend(fontsize=fontsize)
plt.xlabel('epoch',fontsize=fontsize)
plt.ylabel('$F(X,\\theta,\phi)$',fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.show()
# Out:
# [epoch 0]
# train free energy:152.785496419
# test free energy:121.261899805
# [epoch 1]
# train free energy:116.698303402
# test free energy:112.139121484
# [epoch 2]
# train free energy:110.69471709
# test free energy:108.237411133
# [epoch 3]
# train free energy:107.921701074
# test free energy:106.359224902
# [epoch 4]
# train free energy:106.119380046
# test free energy:105.047890918
# [epoch 5]
# train free energy:104.887722054
# test free energy:103.779459863
# [epoch 6]
# train free energy:103.847956722
# test free energy:103.300765527
# [epoch 7]
# train free energy:103.101681722
# test free energy:103.108957227
# [epoch 8]
# train free energy:102.518583529
# test free energy:102.172325879
# [epoch 9]
# train free energy:102.01226901
# test free energy:101.750370117
# [epoch 10]
# train free energy:101.55277277
# test free energy:101.395196973
# [epoch 11]
# train free energy:101.165883496
# test free energy:101.400084863
# [epoch 12]
# train free energy:100.857829899
# test free energy:100.955169336
# [epoch 13]
# train free energy:100.54001543
# test free energy:101.034473633
# [epoch 14]
# train free energy:100.281077262
# test free energy:100.683200391
# [epoch 15]
# train free energy:100.003390381
# test free energy:100.439469727
# [epoch 16]
# train free energy:99.8241788574
# test free energy:100.214968848
# [epoch 17]
# train free energy:99.5877014486
# test free energy:100.269047852
# [epoch 18]
# train free energy:99.4422521322
# test free energy:100.026079883
# [epoch 19]
# train free energy:99.2516979167
# test free energy:100.217574512
# [epoch 20]
# train free energy:99.138975765
# test free energy:100.140233203
# [epoch 21]
# train free energy:98.9338410645
# test free energy:99.9418994141
# [epoch 22]
# train free energy:98.8373764323
# test free energy:99.75339375
# [epoch 23]
# train free energy:98.6609241211
# test free energy:99.3714265625
# [epoch 24]
# train free energy:98.559209668
# test free energy:99.9102444336
# [epoch 25]
# train free energy:98.4623285319
# test free energy:99.2610195312
# [epoch 26]
# train free energy:98.3607570964
# test free energy:99.6426449219
# [epoch 27]
# train free energy:98.195125
# test free energy:99.0339225586
# [epoch 28]
# train free energy:98.1513018229
# test free energy:99.5675928711
# [epoch 29]
# train free energy:98.0366086426
# test free energy:98.9036614258
# [epoch 30]
# train free energy:97.9281079102
# test free energy:99.1459620117
# [epoch 31]
# train free energy:97.8539177409
# test free energy:98.883868457
# [epoch 32]
# train free energy:97.7694575358
# test free energy:99.2695710938
# [epoch 33]
# train free energy:97.7257119629
# test free energy:99.0433231445
# [epoch 34]
# train free energy:97.6307478678
# test free energy:98.8016676758
# [epoch 35]
# train free energy:97.5500369141
# test free energy:98.7406583008
# [epoch 36]
# train free energy:97.4574259277
# test free energy:98.7622157227
# [epoch 37]
# train free energy:97.4395479329
# test free energy:99.6714421875
# [epoch 38]
# train free energy:97.3633341797
# test free energy:99.1163640625
# [epoch 39]
# train free energy:97.2779780762
# test free energy:98.9055160156
# [epoch 40]
# train free energy:97.2362648926
# test free energy:98.9838449219
# [epoch 41]
# train free energy:97.1889952311
# test free energy:98.8103541016
# [epoch 42]
# train free energy:97.0410177897
# test free energy:98.9624473633
# [epoch 43]
# train free energy:97.0654828288
# test free energy:98.6181527344
# [epoch 44]
# train free energy:97.0109656413
# test free energy:98.6274820312
# [epoch 45]
# train free energy:96.9212653646
# test free energy:98.700687793
# [epoch 46]
# train free energy:96.8613812826
# test free energy:98.5856859375
# [epoch 47]
# train free energy:96.8309897135
# test free energy:98.70045625
# [epoch 48]
# train free energy:96.7682312337
# test free energy:98.5180797852
# [epoch 49]
# train free energy:96.7848308105
# test free energy:98.4356553711
# [epoch 50]
# train free energy:96.7146607585
# test free energy:98.2573870117
# [epoch 51]
# train free energy:96.6527725586
# test free energy:98.451515625
# [epoch 52]
# train free energy:96.6085973958
# test free energy:98.3400417969
# [epoch 53]
# train free energy:96.5540781901
# test free energy:98.2080756836
# [epoch 54]
# train free energy:96.5121867839
# test free energy:98.7853552734
# [epoch 55]
# train free energy:96.5006738607
# test free energy:98.4089856445
# [epoch 56]
# train free energy:96.4811797201
# test free energy:98.3522873047
# [epoch 57]
# train free energy:96.3908450846
# test free energy:98.2887898437
# [epoch 58]
# train free energy:96.3885317546
# test free energy:98.3936344727
# [epoch 59]
# train free energy:96.3330464355
# test free energy:98.4747259766
# [epoch 60]
# train free energy:96.2926565104
# test free energy:98.5871259766
# [epoch 61]
# train free energy:96.2642718262
# test free energy:98.5281272461
# [epoch 62]
# train free energy:96.2277570312
# test free energy:98.0081363281
# [epoch 63]
# train free energy:96.169701237
# test free energy:98.3129166016
# [epoch 64]
# train free energy:96.13693514
# test free energy:98.2847481445
# [epoch 65]
# train free energy:96.1366996582
# test free energy:98.116377832
# [epoch 66]
# train free energy:96.1014562012
# test free energy:98.112768457
# [epoch 67]
# train free energy:96.0487751139
# test free energy:98.1175995117
# [epoch 68]
# train free energy:96.10519764
# test free energy:98.1797851563
# [epoch 69]
# train free energy:96.0492868164
# test free energy:97.9228738281
# [epoch 70]
# train free energy:95.9568238281
# test free energy:97.9704779297
# [epoch 71]
# train free energy:95.9539963379
# test free energy:98.2419380859
# [epoch 72]
# train free energy:95.9382193685
# test free energy:97.9220259766
# [epoch 73]
# train free energy:95.8728480632
# test free energy:98.0585703125
# [epoch 74]
# train free energy:95.8334961914
# test free energy:97.8895613281
# [epoch 75]
# train free energy:95.7758965983
# test free energy:98.4885132812
# [epoch 76]
# train free energy:95.7956907389
# test free energy:98.0377670898
# [epoch 77]
# train free energy:95.7864898275
# test free energy:98.1631457031
# [epoch 78]
# train free energy:95.7839020182
# test free energy:98.0070229492
# [epoch 79]
# train free energy:95.7478436198
# test free energy:97.9506650391
# [epoch 80]
# train free energy:95.7289714193
# test free energy:97.9581205078
# [epoch 81]
# train free energy:95.6430854004
# test free energy:98.101490332
# [epoch 82]
# train free energy:95.651982487
# test free energy:98.0144052734
# [epoch 83]
# train free energy:95.6283710775
# test free energy:97.979255957
# [epoch 84]
# train free energy:95.6021784668
# test free energy:98.2677408203
# [epoch 85]
# train free energy:95.5683134277
# test free energy:97.9870222656
# [epoch 86]
# train free energy:95.5856181803
# test free energy:97.789740332
# [epoch 87]
# train free energy:95.5494503092
# test free energy:97.8174476562
# [epoch 88]
# train free energy:95.5258056315
# test free energy:97.8637955078
# [epoch 89]
# train free energy:95.4898547363
# test free energy:98.0305675781
# [epoch 90]
# train free energy:95.4397722331
# test free energy:98.1750641602
# [epoch 91]
# train free energy:95.4683890625
# test free energy:97.8071741211
# [epoch 92]
# train free energy:95.425728418
# test free energy:97.8421228516
# [epoch 93]
# train free energy:95.4442775228
# test free energy:97.7587533203
# [epoch 94]
# train free energy:95.4022873698
# test free energy:97.9705842773
# [epoch 95]
# train free energy:95.408054248
# test free energy:97.8874542969
# [epoch 96]
# train free energy:95.3856055013
# test free energy:97.8323893555
# [epoch 97]
# train free energy:95.3612825033
# test free energy:97.9798081055
# [epoch 98]
# train free energy:95.2695792318
# test free energy:97.8122279297
# [epoch 99]
# train free energy:95.33370389
# test free energy:97.8588049805

# %% [markdown]
# #Reconstruction for test data

# %%
indexes = numpy.random.permutation(10000)   
x_batch = Variable(x_test[indexes[:10]])
x_recon = vae.reconstruct(x_batch)
plt.figure()
for i in xrange(5):
    plt.subplot(2,5,i)
    plt.imshow(x_batch.data[i].reshape(28,28),'binary')
for i in xrange(5):
    plt.subplot(2,5,i+5)
    plt.imshow(x_recon.data[i].reshape(28,28),'binary')
plt.show()

# %% [markdown]
# #Generating samples from p(x)

# %%
x_samples = vae.generate(25,False)
plt.figure()
for i in xrange(25):
    plt.subplot(5,5,i)
    plt.imshow(x_samples.data[i].reshape(28,28),'binary')
plt.show()
